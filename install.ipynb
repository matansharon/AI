# %%
import os

# %%
with open('req.txt', 'r') as f:
    lines=f.readlines()
lines
# Out:
# ['aiohttp                   3.8.5                    pypi_0    pypi\n',
#  'aiosignal                 1.3.1                    pypi_0    pypi\n',
#  'anyio                     3.7.1                    pypi_0    pypi\n',
#  'argon2-cffi               21.3.0                   pypi_0    pypi\n',
#  'argon2-cffi-bindings      21.2.0                   pypi_0    pypi\n',
#  'arrow                     1.2.3                    pypi_0    pypi\n',
#  'asttokens                 2.2.1                    pypi_0    pypi\n',
#  'async-lru                 2.0.3                    pypi_0    pypi\n',
#  'async-timeout             4.0.2                    pypi_0    pypi\n',
#  'attrs                     23.1.0                   pypi_0    pypi\n',
#  'babel                     2.12.1                   pypi_0    pypi\n',
#  'backcall                  0.2.0                    pypi_0    pypi\n',
#  'backoff                   2.2.1                    pypi_0    pypi\n',
# ...

# %%
l=[]
for line in lines:
    l.append(line.strip().split(' '))
print(l)
# Out:
# [['aiohttp', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '3.8.5', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'pypi_0', '', '', '', 'pypi'], ['aiosignal', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '1.3.1', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'pypi_0', '', '', '', 'pypi'], ['anyio', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '3.7.1', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'pypi_0', '', '', '', 'pypi'], ['argon2-cffi', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '21.3.0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'pypi_0', '', '', '', 'pypi'], ['argon2-cffi-bindings', '', '', '', '', '', '21.2.0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'pypi_0', '', '', '', 'pypi'], ['arrow', '', '', '', '', '', '', '', '', '', '', '', 
# ...

# %%
t=''
for i in l:
    # print(i[0])
    t+=i[0]+'\n'
t
# Out:
# 'aiohttp\naiosignal\nanyio\nargon2-cffi\nargon2-cffi-bindings\narrow\nasttokens\nasync-lru\nasync-timeout\nattrs\nbabel\nbackcall\nbackoff\nbeautifulsoup4\nbleach\nbzip2\nca-certificates\ncertifi\ncffi\ncharset-normalizer\nchroma-hnswlib\nchromadb\nclick\ncolorama\ncoloredlogs\ncomm\ndataclasses-json\ndebugpy\ndecorator\ndefusedxml\nexceptiongroup\nexecuting\nfaiss-cpu\nfastapi\nfastjsonschema\nfilelock\nflatbuffers\nfqdn\nfrozenlist\nfsspec\ngreenlet\nh11\nhttptools\nhuggingface-hub\nhumanfriendly\nidna\nimportlib-resources\ninstructorembedding\nipykernel\nipython\nipython-genutils\nipywidgets\nisoduration\njedi\njinja2\njoblib\njson5\njsonpointer\njsonschema\njsonschema-specifications\njupyter\njupyter-client\njupyter-console\njupyter-core\njupyter-events\njupyter-lsp\njupyter-server\njupyter-server-terminals\njupyterlab\njupyterlab-pygments\njupyterlab-server\njupyterlab-widgets\nlangchain\nlangsmith\nlibffi\nmarkupsafe\nmarshmallow\nmatplotlib-inline\nmistune\nmonotonic\nmpmath\n
# ...

# %%
with open('req1.txt','w') as f:
    f.write(t)

# %%
cnt=0
# !conda list
# Out:
# # packages in environment at C:\Users\matan.s\AppData\Local\anaconda3\envs\emb2:
# #
# # Name                    Version                   Build  Channel
# anyio                     3.5.0           py310haa95532_0
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0          py310h2bbff1b_0
# asttokens                 2.0.5              pyhd3eb1b0_0
# attrs                     22.1.0          py310haa95532_0
# babel                     2.11.0          py310haa95532_0
# backcall                  0.2.0              pyhd3eb1b0_0
# beautifulsoup4            4.12.2          py310haa95532_0
# bleach                    4.1.0              pyhd3eb1b0_0
# brotlipy                  0.7.0           py310h2bbff1b_1002
# bzip2                     1.0.8                he774522_0
# ca-certificates           2023.05.30           haa95532_0
# certifi                   2023.7.22       py310haa95532_0
# cffi                      1.15.1          py310h2bbff1b_3
# ...

# %%
# import os
# with open('req1.txt','r')as f:
#     lines=f.readlines()
#     print(lines[cnt])
#     for line in lines:
#         cnt+=1
        
#         os.system('pip install '+lines[cnt])

# %%
s='C:\ePDM_Elcam\System Project\PRS-0003-Genotropin Injector pen\5-Des. V&V\Design Verification\Proof of Design\Essential Performance Identification'
print(len(s))
# Out:
# 144
